# %% [markdown]
# # core
#
# > Fill in a module description here

# %%
#| default_exp core

# %% [markdown]
# ## load data

# %%
import pandas as pd

# %%
df = pd.read_excel('../data/bnc2014sampleforR.xlsx')

# %%
df.head()
# Out:
#    Number of hit Text ID                                       left_context  \
# 0              1    S2GC   swim swam and swum mm there 's not enough pepper
# 1              2    S2UJ  in Suffolk in Suffolk yeah what another helico...
# 2              3    S2XJ           in here no it was lucky you had one come
# 3              4    S38P         so you but if the ground is nice and moist
# 4              5    S38V  're going to have some permanent music set up ...
#
#       node                                      right_context     L3_word  \
# 0  in here       well there 's a whole new thing of pepper we         not
# 1  in here        ? no it 's did n't see it --UNCLEARWORD was  helicopter
# 2  in here     did you ? yeah the dogs chased the chickens oh         had
# 3  in here  and you 've got a moist atmosphere yeah yeah that        nice
# 4  in here   and something probably er do n't need to plug it         set
#
# ...
